# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\HP\\cleaned_imdb.csv")
df
# Out:
#                        Titile  Ratings  Voting_count  Timings   Genre
# 0                    Twisters      6.5      168000.0    122.0  Action
# 1                Gladiator II      6.5      230000.0    148.0  Action
# 2        Sonic the Hedgehog 3      6.9       59000.0    110.0  Action
# 3           Kraven the Hunter      5.5       55000.0    127.0  Action
# 4        Deadpool & Wolverine      7.6      492000.0    128.0  Action
# ..                        ...      ...           ...      ...     ...
# 843  My Spy: The Eternal City      5.7       11000.0    112.0  Comedy
# 844                   Players      5.7       12000.0    105.0  Comedy
# 845                  Sew Torn      6.6      220000.0    100.0  Comedy
# 846     A través de tu mirada      5.4        5200.0    105.0  Comedy
# 847               Space Cadet      5.0       10000.0    110.0  Comedy
#
# [848 rows x 5 columns]

# %%
pip install mysql-connector-python pandas sqlalchemy
# Out:
# ...
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    - -------------------------------------- 0.5/16.4 MB 2.1 MB/s eta 0:00:08
#    -- ------------------------------------- 1.0/16.4 MB 2.0 MB/s eta 0:00:08
#    --- ------------------------------------ 1.3/16.4 MB 2.0 MB/s eta 0:00:08
#    ----- ---------------------------------- 2.1/16.4 MB 2.3 MB/s eta 0:00:07
#    ------ --------------------------------- 2.6/16.4 MB 2.4 MB/s eta 0:00:06
#    -------- ------------------------------- 3.4/16.4 MB 2.7 MB/s eta 0:00:05
#    ---------- ----------------------------- 4.2/16.4 MB 2.8 MB/s eta 0:00:05
#    ---------- ----------------------------- 4.2/16.4 MB 2.8 MB/s eta 0:00:05
#    ---------- ----------------------------- 4.2/16.4 MB 2.8 MB/s eta 0:00:05
#    ---------- ----------------------------- 4.2/16.4 MB 2.8 MB/s eta 0:00:05
# ...

# %%
from sqlalchemy import create_engine

host = "localhost"
user = "root"
password = "tonystark"
database = "IMDB"

engine = create_engine(f"mysql+mysqlconnector://{user}:{password}@{host}/{database}")

df.to_sql(name="scarb_imdb", con=engine, if_exists="replace", index=False)

print("data uploaded successfully")
# Out:
# data uploaded successfully
